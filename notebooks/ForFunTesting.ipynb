# %%
# Step 1: Configure notebook environment and repository path.
from pathlib import Path 
import os
import sys

repo_root = next( # finds the basticTS project proder
    path for path in [Path.cwd(), *Path.cwd().parents]
    if (path / "src" / "basicts").exists()
)
sys.path.insert(0, str(repo_root / "src"))
os.chdir(repo_root)

print("Python executable:", sys.executable)
print("Repo root:", repo_root)
# Out:
# Python executable: c:\Users\luwil\miniconda3\envs\BasicTS\python.exe
# Repo root: c:\Users\luwil\OneDrive\Documents\Code\BasicTS

# %%
import sys

print(sys.executable)
# Out:
# c:\Users\luwil\miniconda3\envs\BasicTS\python.exe

# %%
# !pip list
# Out:
# Package                 Version      Editable project location
# ----------------------- ------------ ----------------------------------------------
# absl-py                 2.3.1
# asttokens               3.0.1
# BasicTS                 1.1.0        C:\Users\luwil\OneDrive\Documents\Code\BasicTS
# blosc2                  3.12.2
# certifi                 2026.1.4
# charset-normalizer      3.4.4
# colorama                0.4.6
# comm                    0.2.3
# debugpy                 1.8.17
# decorator               5.2.1
# easy-torch              1.3.3
# easydict                1.13
# et_xmlfile              2.0.0
# executing               2.2.1
# filelock                3.20.3
# fsspec                  2026.1.0
# grpcio                  1.76.0
# huggingface-hub         0.36.0
# idna                    3.11
# importlib_metadata      8.7.0
# ipykernel               7.1.0
# ipython                 9.8.0
# ipython_pygments_lexers 1.1.1
# jedi                    0.19.2
# Jinja2                  3.1.6
# joblib                  1.5.3
# jupyter_client          8.6.3
# jupyter_core            5.9.1
# Markdown                3.10
# MarkupSafe              3.0.3
# matplotlib-inline       0.2.1
# mpmath                  1.3.0
# msgpack                 1.1.2
# ndindex                 1.10.1
# nest_asyncio            1.6.0
# networkx                3.6.1
# numexpr                 2.14.1
# numpy                   2.4.1
# openpyxl                3.1.5
# packaging               25.0
# pandas                  2.3.3
# parso                   0.8.5
# pillow                  11.3.0
# pip                     25.3
# platformdirs            4.5.1
# prompt_toolkit          3.0.52
# protobuf                6.33.3
# psutil                  7.1.3
# pure_eval               0.2.3
# py-cpuinfo              9.0.0
# Pygments                2.19.2
# python-dateutil         2.9.0.post0
# pytz                    2025.2
# pywin32                 311
# PyYAML                  6.0.3
# pyzmq                   27.1.0
# regex                   2025.11.3
# requests                2.32.5
# safetensors             0.7.0
# scikit-learn            1.8.0
# scipy                   1.17.0
# setproctitle            1.3.7
# setuptools              59.5.0
# six                     1.17.0
# stack_data              0.6.3
# sympy                   1.13.1
# tables                  3.10.2
# tensorboard             2.18.0
# tensorboard-data-server 0.7.2
# threadpoolctl           3.6.0
# tokenizers              0.19.1
# torch                   2.6.0+cu124
# torchaudio              2.6.0+cu124
# torchvision             0.21.0+cu124
# tornado                 6.5.2
# tqdm                    4.67.1
# traitlets               5.14.3
# transformers            4.40.1
# typing_extensions       4.15.0
# tzdata                  2025.3
# urllib3                 2.6.3
# wcwidth                 0.2.14
# Werkzeug                3.1.5
# wheel                   0.45.1
# zipp                    3.23.0
